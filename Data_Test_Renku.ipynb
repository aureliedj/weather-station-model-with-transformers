# %%
# !pip install -r requirements.txt
# Out:
# Collecting peakweather@ git+https://github.com/MeteoSwiss/PeakWeather.git@28a28c2d17f47b8bf33f22ee62fc92adac9b4778 (from -r requirements.txt (line 1))
#   Cloning https://github.com/MeteoSwiss/PeakWeather.git (to revision 28a28c2d17f47b8bf33f22ee62fc92adac9b4778) to /tmp/pip-install-n77uefi3/peakweather_7086d0ea14ef40fcabd0b8d01d281466
#   Running command git clone --filter=blob:none --quiet https://github.com/MeteoSwiss/PeakWeather.git /tmp/pip-install-n77uefi3/peakweather_7086d0ea14ef40fcabd0b8d01d281466
#   Running command git rev-parse -q --verify 'sha^28a28c2d17f47b8bf33f22ee62fc92adac9b4778'
#   Running command git fetch -q https://github.com/MeteoSwiss/PeakWeather.git 28a28c2d17f47b8bf33f22ee62fc92adac9b4778
#   Resolved https://github.com/MeteoSwiss/PeakWeather.git to commit 28a28c2d17f47b8bf33f22ee62fc92adac9b4778
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting torch==2.10.0 (from -r requirements.txt (line 2))
#   Downloading torch-2.10.0-cp313-cp313-manylinux_2_28_x86_64.whl.metadata (31 kB)
# Collecting torchvision==0.25.0 (from -r requirements.txt (line 3))
#   Downloading torchvision-0.25.0-cp313-cp313-manylinux_2_28_x86_64.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy>=1.20 in /layers/paketo-buildpacks_poetry-install/poetry-venv/datascience-python-renku-dependencies-xS3fZVNL-py3.13/lib/python3.13/site-packages (from peakweather@ git+https://github.com/MeteoSwiss/PeakWeather.git@28a28c2d17f47b8bf33f22ee62fc92adac9b4778->-r requirements.txt (line 1)) (2.4.0)
# Requirement already satisfied: pandas>=1.2 in /layers/paketo-buildpacks_poetry-install/poetry-venv/datascience-python-renku-dependencies-xS3fZVNL-py3.13/lib/python3.13/site-packages (from peakweather@ git+https://github.com/MeteoSwiss/PeakWeather.git@28a28c2d17f47b8bf33f22ee62fc92adac9b4778->-r requirements.txt (line 1)) (2.3.3)
# Requirement already satisfied: tqdm>=4.50 in /layers/paketo-buildpacks_poetry-install/poetry-venv/datascience-python-renku-dependencies-xS3fZVNL-py3.13/lib/python3.13/site-packages (from peakweather@ git+https://github.com/MeteoSwiss/PeakWeather.git@28a28c2d17f47b8bf33f22ee62fc92adac9b4778->-r requirements.txt (line 1)) (4.67.1)
# Collecting pyarrow (from peakweather@ git+https://github.com/MeteoSwiss/PeakWeather.git@28a28c2d17f47b8bf33f22ee62fc92adac9b4778->-r requirements.txt (line 1))
#   Using cached pyarrow-23.0.1-cp313-cp313-manylinux_2_28_x86_64.whl.metadata (3.1 kB)
# Requirement already satisfied: filelock in /layers/paketo-buildpacks_poetry-install/poetry-venv/datascience-python-renku-dependencies-xS3fZVNL-py3.13/lib/python3.13/site-packages (from torch==2.10.0->-r requirements.txt (line 2)) (3.20.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /layers/paketo-buildpacks_poetry-install/poetry-venv/datascience-python-renku-dependencies-xS3fZVNL-py3.13/lib/python3.13/site-packages (from torch==2.10.0->-r requirements.txt (line 2)) (4.14.1)
# Requirement already satisfied: setuptools in /layers/paketo-buildpacks_cpython/cpython/lib/python3.13/site-packages (from torch==2.10.0->-r requirements.txt (line 2)) (80.9.0)
# Collecting sympy>=1.13.3 (from torch==2.10.0->-r requirements.txt (line 2))
#   Downloading sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx>=2.5.1 (from torch==2.10.0->-r requirements.txt (line 2))
#   Downloading networkx-3.6.1-py3-none-any.whl.metadata (6.8 kB)
# Collecting jinja2 (from torch==2.10.0->-r requirements.txt (line 2))
#   Downloading jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: fsspec>=0.8.5 in /layers/paketo-buildpacks_poetry-install/poetry-venv/datascience-python-renku-dependencies-xS3fZVNL-py3.13/lib/python3.13/site-packages (from torch==2.10.0->-r requirements.txt (line 2)) (2025.7.0)
# Collecting cuda-bindings==12.9.4 (from torch==2.10.0->-r requirements.txt (line 2))
#   Downloading cuda_bindings-12.9.4-cp313-cp313-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (2.6 kB)
# Collecting nvidia-cuda-nvrtc-cu12==12.8.93 (from torch==2.10.0->-r requirements.txt (line 2))
#   Downloading nvidia_cuda_nvrtc_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cuda-runtime-cu12==12.8.90 (from torch==2.10.0->-r requirements.txt (line 2))
#   Downloading nvidia_cuda_runtime_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cuda-cupti-cu12==12.8.90 (from torch==2.10.0->-r requirements.txt (line 2))
#   Downloading nvidia_cuda_cupti_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cudnn-cu12==9.10.2.21 (from torch==2.10.0->-r requirements.txt (line 2))
#   Downloading nvidia_cudnn_cu12-9.10.2.21-py3-none-manylinux_2_27_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-cublas-cu12==12.8.4.1 (from torch==2.10.0->-r requirements.txt (line 2))
#   Downloading nvidia_cublas_cu12-12.8.4.1-py3-none-manylinux_2_27_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cufft-cu12==11.3.3.83 (from torch==2.10.0->-r requirements.txt (line 2))
#   Downloading nvidia_cufft_cu12-11.3.3.83-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-curand-cu12==10.3.9.90 (from torch==2.10.0->-r requirements.txt (line 2))
#   Downloading nvidia_curand_cu12-10.3.9.90-py3-none-manylinux_2_27_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cusolver-cu12==11.7.3.90 (from torch==2.10.0->-r requirements.txt (line 2))
#   Downloading nvidia_cusolver_cu12-11.7.3.90-py3-none-manylinux_2_27_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-cusparse-cu12==12.5.8.93 (from torch==2.10.0->-r requirements.txt (line 2))
#   Downloading nvidia_cusparse_cu12-12.5.8.93-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-cusparselt-cu12==0.7.1 (from torch==2.10.0->-r requirements.txt (line 2))
#   Downloading nvidia_cusparselt_cu12-0.7.1-py3-none-manylinux2014_x86_64.whl.metadata (7.0 kB)
# Collecting nvidia-nccl-cu12==2.27.5 (from torch==2.10.0->-r requirements.txt (line 2))
#   Downloading nvidia_nccl_cu12-2.27.5-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.0 kB)
# Collecting nvidia-nvshmem-cu12==3.4.5 (from torch==2.10.0->-r requirements.txt (line 2))
#   Downloading nvidia_nvshmem_cu12-3.4.5-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.1 kB)
# Collecting nvidia-nvtx-cu12==12.8.90 (from torch==2.10.0->-r requirements.txt (line 2))
#   Downloading nvidia_nvtx_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvjitlink-cu12==12.8.93 (from torch==2.10.0->-r requirements.txt (line 2))
#   Downloading nvidia_nvjitlink_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cufile-cu12==1.13.1.3 (from torch==2.10.0->-r requirements.txt (line 2))
#   Downloading nvidia_cufile_cu12-1.13.1.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting triton==3.6.0 (from torch==2.10.0->-r requirements.txt (line 2))
#   Downloading triton-3.6.0-cp313-cp313-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /layers/paketo-buildpacks_poetry-install/poetry-venv/datascience-python-renku-dependencies-xS3fZVNL-py3.13/lib/python3.13/site-packages (from torchvision==0.25.0->-r requirements.txt (line 3)) (11.3.0)
# Collecting cuda-pathfinder~=1.1 (from cuda-bindings==12.9.4->torch==2.10.0->-r requirements.txt (line 2))
#   Downloading cuda_pathfinder-1.4.0-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /layers/paketo-buildpacks_poetry-install/poetry-venv/datascience-python-renku-dependencies-xS3fZVNL-py3.13/lib/python3.13/site-packages (from pandas>=1.2->peakweather@ git+https://github.com/MeteoSwiss/PeakWeather.git@28a28c2d17f47b8bf33f22ee62fc92adac9b4778->-r requirements.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /layers/paketo-buildpacks_poetry-install/poetry-venv/datascience-python-renku-dependencies-xS3fZVNL-py3.13/lib/python3.13/site-packages (from pandas>=1.2->peakweather@ git+https://github.com/MeteoSwiss/PeakWeather.git@28a28c2d17f47b8bf33f22ee62fc92adac9b4778->-r requirements.txt (line 1)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /layers/paketo-buildpacks_poetry-install/poetry-venv/datascience-python-renku-dependencies-xS3fZVNL-py3.13/lib/python3.13/site-packages (from pandas>=1.2->peakweather@ git+https://github.com/MeteoSwiss/PeakWeather.git@28a28c2d17f47b8bf33f22ee62fc92adac9b4778->-r requirements.txt (line 1)) (2025.2)
# Requirement already satisfied: six>=1.5 in /layers/paketo-buildpacks_poetry-install/poetry-venv/datascience-python-renku-dependencies-xS3fZVNL-py3.13/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas>=1.2->peakweather@ git+https://github.com/MeteoSwiss/PeakWeather.git@28a28c2d17f47b8bf33f22ee62fc92adac9b4778->-r requirements.txt (line 1)) (1.17.0)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch==2.10.0->-r requirements.txt (line 2))
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->torch==2.10.0->-r requirements.txt (line 2))
#   Downloading markupsafe-3.0.3-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (2.7 kB)
# Downloading torch-2.10.0-cp313-cp313-manylinux_2_28_x86_64.whl (915.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 915.7/915.7 MB 18.3 MB/s  0:00:27m0:00:0100:01
# Downloading torchvision-0.25.0-cp313-cp313-manylinux_2_28_x86_64.whl (8.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 52.6 MB/s  0:00:00
# Downloading cuda_bindings-12.9.4-cp313-cp313-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (11.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.9/11.9 MB 84.0 MB/s  0:00:00
# Downloading nvidia_cublas_cu12-12.8.4.1-py3-none-manylinux_2_27_x86_64.whl (594.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 594.3/594.3 MB 22.2 MB/s  0:00:17m0:00:0100:01
# Downloading nvidia_cuda_cupti_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (10.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 93.8 MB/s  0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (88.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.0/88.0 MB 45.0 MB/s  0:00:01m0:00:01:00:01
# Downloading nvidia_cuda_runtime_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (954 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 954.8/954.8 kB 24.2 MB/s  0:00:00
# Downloading nvidia_cudnn_cu12-9.10.2.21-py3-none-manylinux_2_27_x86_64.whl (706.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 706.8/706.8 MB 20.3 MB/s  0:00:20m0:00:0100:01
# Downloading nvidia_cufft_cu12-11.3.3.83-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (193.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.1/193.1 MB 45.7 MB/s  0:00:04m0:00:0100:01
# Downloading nvidia_cufile_cu12-1.13.1.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 38.0 MB/s  0:00:00
# Downloading nvidia_curand_cu12-10.3.9.90-py3-none-manylinux_2_27_x86_64.whl (63.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.6/63.6 MB 40.3 MB/s  0:00:016m0:00:0100:01
# Downloading nvidia_cusolver_cu12-11.7.3.90-py3-none-manylinux_2_27_x86_64.whl (267.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 267.5/267.5 MB 32.3 MB/s  0:00:08m0:00:0100:01
# Downloading nvidia_cusparse_cu12-12.5.8.93-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (288.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.2/288.2 MB 30.6 MB/s  0:00:08m0:00:0100:01
# Downloading nvidia_cusparselt_cu12-0.7.1-py3-none-manylinux2014_x86_64.whl (287.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 287.2/287.2 MB 35.3 MB/s  0:00:07m0:00:0100:01
# Downloading nvidia_nccl_cu12-2.27.5-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (322.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.3/322.3 MB 28.9 MB/s  0:00:09m0:00:0100:01
# Downloading nvidia_nvjitlink_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (39.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.3/39.3 MB 27.7 MB/s  0:00:01m0:00:0100:01
# Downloading nvidia_nvshmem_cu12-3.4.5-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (139.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.1/139.1 MB 33.8 MB/s  0:00:04m0:00:0100:01
# Downloading nvidia_nvtx_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89 kB)
# Downloading triton-3.6.0-cp313-cp313-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (188.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.3/188.3 MB 42.5 MB/s  0:00:04m0:00:0100:01
# Downloading cuda_pathfinder-1.4.0-py3-none-any.whl (38 kB)
# Downloading networkx-3.6.1-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 65.7 MB/s  0:00:00
# Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 111.2 MB/s  0:00:00
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 7.0 MB/s  0:00:00
# Downloading jinja2-3.1.6-py3-none-any.whl (134 kB)
# Downloading markupsafe-3.0.3-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (22 kB)
# Using cached pyarrow-23.0.1-cp313-cp313-manylinux_2_28_x86_64.whl (47.6 MB)
# Building wheels for collected packages: peakweather
#   Building wheel for peakweather (pyproject.toml) ... done
#   Created wheel for peakweather: filename=peakweather-0.2.1-py3-none-any.whl size=22078 sha256=2a036182d3b5112cccd62877129ae41934b1874ffb8a4edf9264b5074463eb97
#   Stored in directory: /home/renku/.cache/pip/wheels/05/3c/24/6cd2ca8979c91735baebe7166235f5280ace575e1b1c941a04
# Successfully built peakweather
# Installing collected packages: nvidia-cusparselt-cu12, mpmath, triton, sympy, pyarrow, nvidia-nvtx-cu12, nvidia-nvshmem-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufile-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, networkx, MarkupSafe, cuda-pathfinder, nvidia-cusparse-cu12, nvidia-cufft-cu12, nvidia-cudnn-cu12, jinja2, cuda-bindings, peakweather, nvidia-cusolver-cu12, torch, torchvision
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27/27 [torchvision] [torchvision]ver-cu12]2]
# Successfully installed MarkupSafe-3.0.3 cuda-bindings-12.9.4 cuda-pathfinder-1.4.0 jinja2-3.1.6 mpmath-1.3.0 networkx-3.6.1 nvidia-cublas-cu12-12.8.4.1 nvidia-cuda-cupti-cu12-12.8.90 nvidia-cuda-nvrtc-cu12-12.8.93 nvidia-cuda-runtime-cu12-12.8.90 nvidia-cudnn-cu12-9.10.2.21 nvidia-cufft-cu12-11.3.3.83 nvidia-cufile-cu12-1.13.1.3 nvidia-curand-cu12-10.3.9.90 nvidia-cusolver-cu12-11.7.3.90 nvidia-cusparse-cu12-12.5.8.93 nvidia-cusparselt-cu12-0.7.1 nvidia-nccl-cu12-2.27.5 nvidia-nvjitlink-cu12-12.8.93 nvidia-nvshmem-cu12-3.4.5 nvidia-nvtx-cu12-12.8.90 peakweather-0.2.1 pyarrow-23.0.1 sympy-1.14.0 torch-2.10.0 torchvision-0.25.0 triton-3.6.0
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in /layers/paketo-buildpacks_poetry-install/poetry-venv/datascience-python-renku-dependencies-xS3fZVNL-py3.13/lib/python3.13/site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.26.0 in /layers/paketo-buildpacks_poetry-install/poetry-venv/datascience-python-renku-dependencies-xS3fZVNL-py3.13/lib/python3.13/site-packages (from pandas) (2.4.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /layers/paketo-buildpacks_poetry-install/poetry-venv/datascience-python-renku-dependencies-xS3fZVNL-py3.13/lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /layers/paketo-buildpacks_poetry-install/poetry-venv/datascience-python-renku-dependencies-xS3fZVNL-py3.13/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /layers/paketo-buildpacks_poetry-install/poetry-venv/datascience-python-renku-dependencies-xS3fZVNL-py3.13/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /layers/paketo-buildpacks_poetry-install/poetry-venv/datascience-python-renku-dependencies-xS3fZVNL-py3.13/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
from peakweather.dataset import PeakWeatherDataset
import os
import pandas as pd

# %%
current_path = os.getcwd()
print(current_path)
# Out:
# /home/renku/work/weather-station-model-with-transformers

# %%
path_csv = "../polybox-capstone/prediction.csv"

data = pd.read_csv(path_csv)

print(data.head())
# Out:
#       Id           y
# 0  10000  -66.002423
# 1  10001  451.406504
# 2  10002 -461.676417
# 3  10003   40.501209
# 4  10004 -126.744722

# %%
#Load Local Dataset
ds = PeakWeatherDataset(root="../polybox-capstone/PeakWeatherDataset")
